# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Titanic-Dataset.csv")

# %% [markdown]
# # Easy

# %% [markdown]
# How do you load the Titanic CSV into a DataFrame?

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              BRAUND, MR. OWEN HARRIS    male  22.0      1
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.0      1
# 2                               HEIKKINEN, MISS. LAINA  female  26.0      0
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.0      1
# 4                             ALLEN, MR. WILLIAM HENRY    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              MONTVILA, REV. JUOZAS    male  27.0      0
# 887                       GRAHAM, MISS. MARGARET EDITH  female  19.0      0
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female   NaN      1
# 889                              BEHR, MR. KARL HOWELL    male  26.0      0
# 890                                DOOLEY, MR. PATRICK    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked         FareBucket
# 0        0         A/5 21171   7.2500   NaN        S    (-0.001, 7.854]
# 1        0          PC 17599  71.2833   C85        C  (39.688, 512.329]
# 2        0  STON/O2. 3101282   7.9250   NaN        S      (7.854, 10.5]
# 3        0            113803  53.1000  C123        S  (39.688, 512.329]
# 4        0            373450   8.0500   NaN        S      (7.854, 10.5]
# ..     ...               ...      ...   ...      ...                ...
# 886      0            211536  13.0000   NaN        S     (10.5, 21.679]
# 887      0            112053  30.0000   B42        S   (21.679, 39.688]
# 888      2        W./C. 6607  23.4500   NaN        S   (21.679, 39.688]
# 889      0            111369  30.0000  C148        C   (21.679, 39.688]
# 890      0            370376   7.7500   NaN        Q    (-0.001, 7.854]
#
# [891 rows x 13 columns]

# %% [markdown]
# How do you view the first 5 rows?

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            BRAUND, MR. OWEN HARRIS    male  22.0      1
# 1  CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.0      1
# 2                             HEIKKINEN, MISS. LAINA  female  26.0      0
# 3       FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.0      1
# 4                           ALLEN, MR. WILLIAM HENRY    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked         FareBucket
# 0      0         A/5 21171   7.2500   NaN        S    (-0.001, 7.854]
# 1      0          PC 17599  71.2833   C85        C  (39.688, 512.329]
# 2      0  STON/O2. 3101282   7.9250   NaN        S      (7.854, 10.5]
# 3      0            113803  53.1000  C123        S  (39.688, 512.329]
# 4      0            373450   8.0500   NaN        S      (7.854, 10.5]

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        MARKUN, MR. JOHANN
# 882          883         0       3              DAHLBERG, MISS. GERDA ULRIKA
# 883          884         0       2             BANFIELD, MR. FREDERICK JAMES
# 884          885         0       3                    SUTEHALL, MR. HENRY JR
# 885          886         0       3      RICE, MRS. WILLIAM (MARGARET NORTON)
# 886          887         0       2                     MONTVILA, REV. JUOZAS
# 887          888         1       1              GRAHAM, MISS. MARGARET EDITH
# 888          889         0       3  JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889          890         1       1                     BEHR, MR. KARL HOWELL
# 890          891         0       3                       DOOLEY, MR. PATRICK
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 881    male  33.0      0      0            349257   7.8958   NaN        S
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 883    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
#            FareBucket
# 881     (7.854, 10.5]
# 882    (10.5, 21.679]
# 883     (7.854, 10.5]
# 884   (-0.001, 7.854]
# 885  (21.679, 39.688]
# 886    (10.5, 21.679]
# 887  (21.679, 39.688]
# 888  (21.679, 39.688]
# 889  (21.679, 39.688]
# 890   (-0.001, 7.854]

# %% [markdown]
# How do you get the shape of the dataset?

# %%
df.shape
# Out:
# (891, 13)

# %% [markdown]
# How do you list all column names?

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'FareBucket'],
#       dtype='object')

# %% [markdown]
# How many rows are present in the dataset?

# %%
len(df)
# Out:
# 891

# %% [markdown]
# How do you check the datatype of each column?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  FareBucket   891 non-null    category
# dtypes: category(1), float64(2), int64(5), object(5)
# memory usage: 84.8+ KB

# %% [markdown]
# How many missing values does each column have?

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked  FareBucket
# 0    False   True     False       False
# 1    False  False     False       False
# 2    False   True     False       False
# 3    False  False     False       False
# 4    False   True     False       False
# ..     ...    ...       ...         ...
# 886  False   True     False       False
# 887  False  False     False       False
# 888  False   True     False       False
# 889  False  False     False       False
# 890  False   True     False       False
#
# [891 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# FareBucket       0
# dtype: int64

# %% [markdown]
# How do you get summary statistics for numerical columns?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# How do you display only the ‘Name’ column?

# %%
df["Name"]
# Out:
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# 3           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                               ALLEN, MR. WILLIAM HENRY
#                              ...
# 886                                MONTVILA, REV. JUOZAS
# 887                         GRAHAM, MISS. MARGARET EDITH
# 888             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889                                BEHR, MR. KARL HOWELL
# 890                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# How do you select first 10 values in the ‘Age’ column?

# %%
df["Age"].head(10)
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %% [markdown]
# How do you filter passengers older than 50?

# %%
df.loc[(df["Age"]>=50)]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 54            55         0       1
# ..           ...       ...     ...
# 820          821         1       1
# 829          830         1       1
# 851          852         0       3
# 857          858         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              MCCARTHY, MR. TIMOTHY J    male  54.0      0
# 11                            BONNELL, MISS. ELIZABETH  female  58.0      0
# 15                    HEWLETT, MRS. (MARY D KINGCOME)   female  55.0      0
# 33                               WHEADON, MR. EDWARD H    male  66.0      0
# 54                      OSTBY, MR. ENGELHART CORNELIUS    male  65.0      0
# ..                                                 ...     ...   ...    ...
# 820  HAYS, MRS. CHARLES MELVILLE (CLARA JENNINGS GR...  female  52.0      1
# 829          STONE, MRS. GEORGE NELSON (MARTHA EVELYN)  female  62.0      0
# 851                                SVENSSON, MR. JOHAN    male  74.0      0
# 857                             DALY, MR. PETER DENIS     male  51.0      0
# 879      POTTER, MRS. THOMAS JR (LILY ALEXENIA WILSON)  female  56.0      0
#
#      Parch      Ticket     Fare Cabin Embarked         FareBucket
# 6        0       17463  51.8625   E46        S  (39.688, 512.329]
# 11       0      113783  26.5500  C103        S   (21.679, 39.688]
# 15       0      248706  16.0000   NaN        S     (10.5, 21.679]
# 33       0  C.A. 24579  10.5000   NaN        S      (7.854, 10.5]
# 54       1      113509  61.9792   B30        C  (39.688, 512.329]
# ..     ...         ...      ...   ...      ...                ...
# 820      1       12749  93.5000   B69        S  (39.688, 512.329]
# 829      0      113572  80.0000   B28      NaN  (39.688, 512.329]
# 851      0      347060   7.7750   NaN        S    (-0.001, 7.854]
# 857      0      113055  26.5500   E17        S   (21.679, 39.688]
# 879      1       11767  83.1583   C50        C  (39.688, 512.329]
#
# [74 rows x 13 columns]

# %% [markdown]
# How do you filter passengers who survived?

# %%
df.loc[(df["Survived"]==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.0      1
# 2                               HEIKKINEN, MISS. LAINA  female  26.0      0
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.0      1
# 8    JOHNSON, MRS. OSCAR W (ELISABETH VILHELMINA BERG)  female  27.0      0
# 9                  NASSER, MRS. NICHOLAS (ADELE ACHEM)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 875                   NAJIB, MISS. ADELE KIAMIE "JANE"  female  15.0      0
# 879      POTTER, MRS. THOMAS JR (LILY ALEXENIA WILSON)  female  56.0      0
# 880       SHELLEY, MRS. WILLIAM (IMANITA PARRISH HALL)  female  25.0      0
# 887                       GRAHAM, MISS. MARGARET EDITH  female  19.0      0
# 889                              BEHR, MR. KARL HOWELL    male  26.0      0
#
#      Parch            Ticket     Fare Cabin Embarked         FareBucket
# 1        0          PC 17599  71.2833   C85        C  (39.688, 512.329]
# 2        0  STON/O2. 3101282   7.9250   NaN        S      (7.854, 10.5]
# 3        0            113803  53.1000  C123        S  (39.688, 512.329]
# 8        2            347742  11.1333   NaN        S     (10.5, 21.679]
# 9        0            237736  30.0708   NaN        C   (21.679, 39.688]
# ..     ...               ...      ...   ...      ...                ...
# 875      0              2667   7.2250   NaN        C    (-0.001, 7.854]
# 879      1             11767  83.1583   C50        C  (39.688, 512.329]
# 880      1            230433  26.0000   NaN        S   (21.679, 39.688]
# 887      0            112053  30.0000   B42        S   (21.679, 39.688]
# 889      0            111369  30.0000  C148        C   (21.679, 39.688]
#
# [342 rows x 13 columns]

# %% [markdown]
# How do you select all rows where Sex == "female"?

# %%
df.loc[(df["Sex"]=="female")]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.0      1
# 2                               HEIKKINEN, MISS. LAINA  female  26.0      0
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.0      1
# 8    JOHNSON, MRS. OSCAR W (ELISABETH VILHELMINA BERG)  female  27.0      0
# 9                  NASSER, MRS. NICHOLAS (ADELE ACHEM)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 880       SHELLEY, MRS. WILLIAM (IMANITA PARRISH HALL)  female  25.0      0
# 882                       DAHLBERG, MISS. GERDA ULRIKA  female  22.0      0
# 885               RICE, MRS. WILLIAM (MARGARET NORTON)  female  39.0      0
# 887                       GRAHAM, MISS. MARGARET EDITH  female  19.0      0
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female   NaN      1
#
#      Parch            Ticket     Fare Cabin Embarked         FareBucket
# 1        0          PC 17599  71.2833   C85        C  (39.688, 512.329]
# 2        0  STON/O2. 3101282   7.9250   NaN        S      (7.854, 10.5]
# 3        0            113803  53.1000  C123        S  (39.688, 512.329]
# 8        2            347742  11.1333   NaN        S     (10.5, 21.679]
# 9        0            237736  30.0708   NaN        C   (21.679, 39.688]
# ..     ...               ...      ...   ...      ...                ...
# 880      1            230433  26.0000   NaN        S   (21.679, 39.688]
# 882      0              7552  10.5167   NaN        S     (10.5, 21.679]
# 885      5            382652  29.1250   NaN        Q   (21.679, 39.688]
# 887      0            112053  30.0000   B42        S   (21.679, 39.688]
# 888      2        W./C. 6607  23.4500   NaN        S   (21.679, 39.688]
#
# [314 rows x 13 columns]

# %% [markdown]
# How many passengers embarked from "S"?

# %%
df.loc[(df["Embarked"]=="S")]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         BRAUND, MR. OWEN HARRIS    male  22.0      1      0
# 2                          HEIKKINEN, MISS. LAINA  female  26.0      0      0
# 3    FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.0      1      0
# 4                        ALLEN, MR. WILLIAM HENRY    male  35.0      0      0
# 6                         MCCARTHY, MR. TIMOTHY J    male  54.0      0      0
# ..                                            ...     ...   ...    ...    ...
# 883                 BANFIELD, MR. FREDERICK JAMES    male  28.0      0      0
# 884                        SUTEHALL, MR. HENRY JR    male  25.0      0      0
# 886                         MONTVILA, REV. JUOZAS    male  27.0      0      0
# 887                  GRAHAM, MISS. MARGARET EDITH  female  19.0      0      0
# 888      JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female   NaN      1      2
#
#                Ticket     Fare Cabin Embarked         FareBucket
# 0           A/5 21171   7.2500   NaN        S    (-0.001, 7.854]
# 2    STON/O2. 3101282   7.9250   NaN        S      (7.854, 10.5]
# 3              113803  53.1000  C123        S  (39.688, 512.329]
# 4              373450   8.0500   NaN        S      (7.854, 10.5]
# 6               17463  51.8625   E46        S  (39.688, 512.329]
# ..                ...      ...   ...      ...                ...
# 883  C.A./SOTON 34068  10.5000   NaN        S      (7.854, 10.5]
# 884   SOTON/OQ 392076   7.0500   NaN        S    (-0.001, 7.854]
# 886            211536  13.0000   NaN        S     (10.5, 21.679]
# 887            112053  30.0000   B42        S   (21.679, 39.688]
# 888        W./C. 6607  23.4500   NaN        S   (21.679, 39.688]
#
# [644 rows x 13 columns]

# %% [markdown]
# How do you sort by Age (ascending)?

# %%
df.sort_values("Age")
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           THOMAS, MASTER. ASSAD ALEXANDER
# 755          756         1       2                 HAMALAINEN, MASTER. VILJO
# 644          645         1       3                    BACLINI, MISS. EUGENIE
# 469          470         1       3             BACLINI, MISS. HELENE BARBARA
# 78            79         1       2             CALDWELL, MASTER. ALDEN GATES
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          RAZI, MR. RAIHED
# 863          864         0       3         SAGE, MISS. DOROTHY EDITH "DOLLY"
# 868          869         0       3               VAN MELKEBEKE, MR. PHILEMON
# 878          879         0       3                        LALEFF, MR. KRISTO
# 888          889         0       3  JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  \
# 803    male  0.42      0      1        2625   8.5167   NaN        C
# 755    male  0.67      1      1      250649  14.5000   NaN        S
# 644  female  0.75      2      1        2666  19.2583   NaN        C
# 469  female  0.75      2      1        2666  19.2583   NaN        C
# 78     male  0.83      0      2      248738  29.0000   NaN        S
# ..      ...   ...    ...    ...         ...      ...   ...      ...
# 859    male   NaN      0      0        2629   7.2292   NaN        C
# 863  female   NaN      8      2    CA. 2343  69.5500   NaN        S
# 868    male   NaN      0      0      345777   9.5000   NaN        S
# 878    male   NaN      0      0      349217   7.8958   NaN        S
# 888  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
#
#             FareBucket
# 803      (7.854, 10.5]
# 755     (10.5, 21.679]
# 644     (10.5, 21.679]
# 469     (10.5, 21.679]
# 78    (21.679, 39.688]
# ..                 ...
# 859    (-0.001, 7.854]
# 863  (39.688, 512.329]
# 868      (7.854, 10.5]
# 878      (7.854, 10.5]
# 888   (21.679, 39.688]
#
# [891 rows x 13 columns]

# %% [markdown]
# How do you sort by Fare (descending)?

# %%
df.sort_values(by="Fare",ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 679          680         1       1  CARDEZA, MR. THOMAS DRAKE MARTINEZ
# 258          259         1       1                    WARD, MISS. ANNA
# 737          738         1       1              LESURER, MR. GUSTAVE J
# 88            89         1       1          FORTUNE, MISS. MABEL HELEN
# 438          439         0       1                   FORTUNE, MR. MARK
# ..           ...       ...     ...                                 ...
# 806          807         0       1              ANDREWS, MR. THOMAS JR
# 815          816         0       1                    FRY, MR. RICHARD
# 466          467         0       2               CAMPBELL, MR. WILLIAM
# 481          482         0       2    FROST, MR. ANTHONY WOOD "ARCHIE"
# 822          823         0       1     REUCHLIN, JONKHEER. JOHN GEORGE
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S
# 438    male  64.0      1      4     19950  263.0000  C23 C25 C27        S
# ..      ...   ...    ...    ...       ...       ...          ...      ...
# 806    male  39.0      0      0    112050    0.0000          A36        S
# 815    male   NaN      0      0    112058    0.0000         B102        S
# 466    male   NaN      0      0    239853    0.0000          NaN        S
# 481    male   NaN      0      0    239854    0.0000          NaN        S
# 822    male  38.0      0      0     19972    0.0000          NaN        S
#
#             FareBucket
# 679  (39.688, 512.329]
# 258  (39.688, 512.329]
# 737  (39.688, 512.329]
# 88   (39.688, 512.329]
# 438  (39.688, 512.329]
# ..                 ...
# 806    (-0.001, 7.854]
# 815    (-0.001, 7.854]
# 466    (-0.001, 7.854]
# 481    (-0.001, 7.854]
# 822    (-0.001, 7.854]
#
# [891 rows x 13 columns]

# %% [markdown]
# How do you check how many unique Ticket values exist?

# %%
df["Ticket"].nunique()
# Out:
# 681

# %% [markdown]
# How do you drop the Cabin column?

# %%
temp = df.drop(columns="Cabin")

# %%
temp = df.drop("Cabin",axis=1)
temp
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              BRAUND, MR. OWEN HARRIS    male  22.0      1
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.0      1
# 2                               HEIKKINEN, MISS. LAINA  female  26.0      0
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.0      1
# 4                             ALLEN, MR. WILLIAM HENRY    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              MONTVILA, REV. JUOZAS    male  27.0      0
# 887                       GRAHAM, MISS. MARGARET EDITH  female  19.0      0
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female   NaN      1
# 889                              BEHR, MR. KARL HOWELL    male  26.0      0
# 890                                DOOLEY, MR. PATRICK    male  32.0      0
#
#      Parch            Ticket     Fare Embarked         FareBucket
# 0        0         A/5 21171   7.2500        S    (-0.001, 7.854]
# 1        0          PC 17599  71.2833        C  (39.688, 512.329]
# 2        0  STON/O2. 3101282   7.9250        S      (7.854, 10.5]
# 3        0            113803  53.1000        S  (39.688, 512.329]
# 4        0            373450   8.0500        S      (7.854, 10.5]
# ..     ...               ...      ...      ...                ...
# 886      0            211536  13.0000        S     (10.5, 21.679]
# 887      0            112053  30.0000        S   (21.679, 39.688]
# 888      2        W./C. 6607  23.4500        S   (21.679, 39.688]
# 889      0            111369  30.0000        C   (21.679, 39.688]
# 890      0            370376   7.7500        Q    (-0.001, 7.854]
#
# [891 rows x 12 columns]

# %% [markdown]
# How do you rename “Sex” to “Gender”?

# %%
df = df.rename({"Sex":"Gender"},axis=1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              BRAUND, MR. OWEN HARRIS    male  22.0      1
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.0      1
# 2                               HEIKKINEN, MISS. LAINA  female  26.0      0
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.0      1
# 4                             ALLEN, MR. WILLIAM HENRY    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              MONTVILA, REV. JUOZAS    male  27.0      0
# 887                       GRAHAM, MISS. MARGARET EDITH  female  19.0      0
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female   NaN      1
# 889                              BEHR, MR. KARL HOWELL    male  26.0      0
# 890                                DOOLEY, MR. PATRICK    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked         FareBucket
# 0        0         A/5 21171   7.2500   NaN        S    (-0.001, 7.854]
# 1        0          PC 17599  71.2833   C85        C  (39.688, 512.329]
# 2        0  STON/O2. 3101282   7.9250   NaN        S      (7.854, 10.5]
# 3        0            113803  53.1000  C123        S  (39.688, 512.329]
# 4        0            373450   8.0500   NaN        S      (7.854, 10.5]
# ..     ...               ...      ...   ...      ...                ...
# 886      0            211536  13.0000   NaN        S     (10.5, 21.679]
# 887      0            112053  30.0000   B42        S   (21.679, 39.688]
# 888      2        W./C. 6607  23.4500   NaN        S   (21.679, 39.688]
# 889      0            111369  30.0000  C148        C   (21.679, 39.688]
# 890      0            370376   7.7500   NaN        Q    (-0.001, 7.854]
#
# [891 rows x 13 columns]

# %% [markdown]
# # LEVEL 2 — MEDIUM (21–40)

# %% [markdown]
# Display rows where Age is between 20 and 40.

# %%
df.loc[(df["Age"]>=20)&(df["Age"]<=40)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              BRAUND, MR. OWEN HARRIS    male  22.0      1
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.0      1
# 2                               HEIKKINEN, MISS. LAINA  female  26.0      0
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.0      1
# 4                             ALLEN, MR. WILLIAM HENRY    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 884                             SUTEHALL, MR. HENRY JR    male  25.0      0
# 885               RICE, MRS. WILLIAM (MARGARET NORTON)  female  39.0      0
# 886                              MONTVILA, REV. JUOZAS    male  27.0      0
# 889                              BEHR, MR. KARL HOWELL    male  26.0      0
# 890                                DOOLEY, MR. PATRICK    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked         FareBucket
# 0        0         A/5 21171   7.2500   NaN        S    (-0.001, 7.854]
# 1        0          PC 17599  71.2833   C85        C  (39.688, 512.329]
# 2        0  STON/O2. 3101282   7.9250   NaN        S      (7.854, 10.5]
# 3        0            113803  53.1000  C123        S  (39.688, 512.329]
# 4        0            373450   8.0500   NaN        S      (7.854, 10.5]
# ..     ...               ...      ...   ...      ...                ...
# 884      0   SOTON/OQ 392076   7.0500   NaN        S    (-0.001, 7.854]
# 885      5            382652  29.1250   NaN        Q   (21.679, 39.688]
# 886      0            211536  13.0000   NaN        S     (10.5, 21.679]
# 889      0            111369  30.0000  C148        C   (21.679, 39.688]
# 890      0            370376   7.7500   NaN        Q    (-0.001, 7.854]
#
# [400 rows x 13 columns]

# %% [markdown]
# Filter passengers who paid more than 100 in Fare.

# %%
df.loc[(df["Fare"]>=100)]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# 390          391         1       1
# 393          394         1       1
# 435          436         1       1
# 438          439         0       1
# 498          499         0       1
# 505          506         0       1
# 527          528         0       1
# 537          538         1       1
# 544          545         0       1
# 550          551         1       1
# 557          558         0       1
# 581          582         1       1
# 609          610         1       1
# 659          660         0       1
# 660          661         1       1
# 679          680         1       1
# 689          690         1       1
# 698          699         0       1
# 700          701         1       1
# 708          709         1       1
# 716          717         1       1
# 730          731         1       1
# 737          738         1       1
# 742          743         1       1
# 763          764         1       1
# 779          780         1       1
# 802          803         1       1
# 856          857         1       1
#
#                                                   Name  Gender    Age  SibSp  \
# 27                      FORTUNE, MR. CHARLES ALEXANDER    male  19.00      3
# 31      SPENCER, MRS. WILLIAM AUGUSTUS (MARIE EUGENIE)  female    NaN      1
# 88                          FORTUNE, MISS. MABEL HELEN  female  23.00      3
# 118                           BAXTER, MR. QUIGG EDMOND    male  24.00      0
# 195                               LURETTE, MISS. ELISE  female  58.00      0
# 215                            NEWELL, MISS. MADELEINE  female  31.00      1
# 258                                   WARD, MISS. ANNA  female  35.00      0
# 268      GRAHAM, MRS. WILLIAM THOMPSON (EDITH JUNKINS)  female  58.00      0
# 269                             BISSETTE, MISS. AMELIA  female  35.00      0
# 297                       ALLISON, MISS. HELEN LORAINE  female   2.00      1
# 299    BAXTER, MRS. JAMES (HELENE DELAUDENIERE CHAPUT)  female  50.00      0
# 305                     ALLISON, MASTER. HUDSON TREVOR    male   0.92      1
# 306                            FLEMING, MISS. MARGARET  female    NaN      0
# 307  PENASCO Y CASTELLANA, MRS. VICTOR DE SATODE (M...  female  17.00      1
# 311                         RYERSON, MISS. EMILY BORIE  female  18.00      2
# 318                           WICK, MISS. MARY NATALIE  female  31.00      0
# 319  SPEDDEN, MRS. FREDERIC OAKLEY (MARGARETTA CORN...  female  40.00      1
# 325                           YOUNG, MISS. MARIE GRICE  female  36.00      0
# 332                          GRAHAM, MR. GEORGE EDWARD    male  38.00      0
# 334  FRAUENTHAL, MRS. HENRY WILLIAM (CLARA HEINSHEI...  female    NaN      1
# 337                    BURNS, MISS. ELIZABETH MARGARET  female  41.00      0
# 341                     FORTUNE, MISS. ALICE ELIZABETH  female  24.00      3
# 373                                RINGHINI, MR. SANTE    male  22.00      0
# 377                          WIDENER, MR. HARRY ELKINS    male  27.00      0
# 380                              BIDOIS, MISS. ROSALIE  female  42.00      0
# 390                         CARTER, MR. WILLIAM ERNEST    male  36.00      1
# 393                             NEWELL, MISS. MARJORIE  female  23.00      1
# 435                          CARTER, MISS. LUCILE POLK  female  14.00      1
# 438                                  FORTUNE, MR. MARK    male  64.00      1
# 498    ALLISON, MRS. HUDSON J C (BESSIE WALDO DANIELS)  female  25.00      1
# 505         PENASCO Y CASTELLANA, MR. VICTOR DE SATODE    male  18.00      1
# 527                                 FARTHING, MR. JOHN    male    NaN      0
# 537                                LEROY, MISS. BERTHA  female  30.00      0
# 544                         DOUGLAS, MR. WALTER DONALD    male  50.00      1
# 550                        THAYER, MR. JOHN BORLAND JR    male  17.00      0
# 557                                ROBBINS, MR. VICTOR    male    NaN      0
# 581  THAYER, MRS. JOHN BORLAND (MARIAN LONGSTRETH M...  female  39.00      1
# 609                          SHUTES, MISS. ELIZABETH W  female  40.00      0
# 659                         NEWELL, MR. ARTHUR WEBSTER    male  58.00      0
# 660                      FRAUENTHAL, DR. HENRY WILLIAM    male  50.00      2
# 679                 CARDEZA, MR. THOMAS DRAKE MARTINEZ    male  36.00      0
# 689                  MADILL, MISS. GEORGETTE ALEXANDRA  female  15.00      0
# 698                           THAYER, MR. JOHN BORLAND    male  49.00      1
# 700  ASTOR, MRS. JOHN JACOB (MADELEINE TALMADGE FORCE)  female  18.00      1
# 708                               CLEAVER, MISS. ALICE  female  22.00      0
# 716                      ENDRES, MISS. CAROLINE LOUISE  female  38.00      0
# 730                      ALLEN, MISS. ELISABETH WALTON  female  29.00      0
# 737                             LESURER, MR. GUSTAVE J    male  35.00      0
# 742              RYERSON, MISS. SUSAN PARKER "SUZETTE"  female  21.00      2
# 763          CARTER, MRS. WILLIAM ERNEST (LUCILE POLK)  female  36.00      1
# 779  ROBERT, MRS. EDWARD SCOTT (ELISABETH WALTON MC...  female  43.00      0
# 802                CARTER, MASTER. WILLIAM THORNTON II    male  11.00      1
# 856         WICK, MRS. GEORGE DENNICK (MARY HITCHCOCK)  female  45.00      1
#
#      Parch    Ticket      Fare            Cabin Embarked         FareBucket
# 27       2     19950  263.0000      C23 C25 C27        S  (39.688, 512.329]
# 31       0  PC 17569  146.5208              B78        C  (39.688, 512.329]
# 88       2     19950  263.0000      C23 C25 C27        S  (39.688, 512.329]
# 118      1  PC 17558  247.5208          B58 B60        C  (39.688, 512.329]
# 195      0  PC 17569  146.5208              B80        C  (39.688, 512.329]
# 215      0     35273  113.2750              D36        C  (39.688, 512.329]
# 258      0  PC 17755  512.3292              NaN        C  (39.688, 512.329]
# 268      1  PC 17582  153.4625             C125        S  (39.688, 512.329]
# 269      0  PC 17760  135.6333              C99        S  (39.688, 512.329]
# 297      2    113781  151.5500          C22 C26        S  (39.688, 512.329]
# 299      1  PC 17558  247.5208          B58 B60        C  (39.688, 512.329]
# 305      2    113781  151.5500          C22 C26        S  (39.688, 512.329]
# 306      0     17421  110.8833              NaN        C  (39.688, 512.329]
# 307      0  PC 17758  108.9000              C65        C  (39.688, 512.329]
# 311      2  PC 17608  262.3750  B57 B59 B63 B66        C  (39.688, 512.329]
# 318      2     36928  164.8667               C7        S  (39.688, 512.329]
# 319      1     16966  134.5000              E34        C  (39.688, 512.329]
# 325      0  PC 17760  135.6333              C32        C  (39.688, 512.329]
# 332      1  PC 17582  153.4625              C91        S  (39.688, 512.329]
# 334      0  PC 17611  133.6500              NaN        S  (39.688, 512.329]
# 337      0     16966  134.5000              E40        C  (39.688, 512.329]
# 341      2     19950  263.0000      C23 C25 C27        S  (39.688, 512.329]
# 373      0  PC 17760  135.6333              NaN        C  (39.688, 512.329]
# 377      2    113503  211.5000              C82        C  (39.688, 512.329]
# 380      0  PC 17757  227.5250              NaN        C  (39.688, 512.329]
# 390      2    113760  120.0000          B96 B98        S  (39.688, 512.329]
# 393      0     35273  113.2750              D36        C  (39.688, 512.329]
# 435      2    113760  120.0000          B96 B98        S  (39.688, 512.329]
# 438      4     19950  263.0000      C23 C25 C27        S  (39.688, 512.329]
# 498      2    113781  151.5500          C22 C26        S  (39.688, 512.329]
# 505      0  PC 17758  108.9000              C65        C  (39.688, 512.329]
# 527      0  PC 17483  221.7792              C95        S  (39.688, 512.329]
# 537      0  PC 17761  106.4250              NaN        C  (39.688, 512.329]
# 544      0  PC 17761  106.4250              C86        C  (39.688, 512.329]
# 550      2     17421  110.8833              C70        C  (39.688, 512.329]
# 557      0  PC 17757  227.5250              NaN        C  (39.688, 512.329]
# 581      1     17421  110.8833              C68        C  (39.688, 512.329]
# 609      0  PC 17582  153.4625             C125        S  (39.688, 512.329]
# 659      2     35273  113.2750              D48        C  (39.688, 512.329]
# 660      0  PC 17611  133.6500              NaN        S  (39.688, 512.329]
# 679      1  PC 17755  512.3292      B51 B53 B55        C  (39.688, 512.329]
# 689      1     24160  211.3375               B5        S  (39.688, 512.329]
# 698      1     17421  110.8833              C68        C  (39.688, 512.329]
# 700      0  PC 17757  227.5250          C62 C64        C  (39.688, 512.329]
# 708      0    113781  151.5500              NaN        S  (39.688, 512.329]
# 716      0  PC 17757  227.5250              C45        C  (39.688, 512.329]
# 730      0     24160  211.3375               B5        S  (39.688, 512.329]
# 737      0  PC 17755  512.3292             B101        C  (39.688, 512.329]
# 742      2  PC 17608  262.3750  B57 B59 B63 B66        C  (39.688, 512.329]
# 763      2    113760  120.0000          B96 B98        S  (39.688, 512.329]
# 779      1     24160  211.3375               B3        S  (39.688, 512.329]
# 802      2    113760  120.0000          B96 B98        S  (39.688, 512.329]
# 856      1     36928  164.8667              NaN        S  (39.688, 512.329]

# %% [markdown]
# Count number of male vs female passengers.

# %%
df.groupby("Gender").count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Gender
# female          314       314     314   314  261    314    314     314   314
# male            577       577     577   577  453    577    577     577   577
#
#         Cabin  Embarked  FareBucket
# Gender
# female     97       312         314
# male      107       577         577

# %% [markdown]
# What is the average fare by Pclass?

# %%
df.groupby("Pclass")["Fare"].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %% [markdown]
# What is the average age of survivors vs non-survivors?

# %%
df.groupby("Survived")["Age"].mean()
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %%
df.sort_values(by="Age",ascending=False).head(5)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  BARKWORTH, MR. ALGERNON HENRY WILSON
# 851          852         0       3                   SVENSSON, MR. JOHAN
# 493          494         0       1               ARTAGAVEYTIA, MR. RAMON
# 96            97         0       1             GOLDSCHMIDT, MR. GEORGE B
# 116          117         0       3                  CONNORS, MR. PATRICK
#
#     Gender   Age  SibSp  Parch    Ticket     Fare Cabin Embarked  \
# 630   male  80.0      0      0     27042  30.0000   A23        S
# 851   male  74.0      0      0    347060   7.7750   NaN        S
# 493   male  71.0      0      0  PC 17609  49.5042   NaN        C
# 96    male  71.0      0      0  PC 17754  34.6542    A5        C
# 116   male  70.5      0      0    370369   7.7500   NaN        Q
#
#             FareBucket
# 630   (21.679, 39.688]
# 851    (-0.001, 7.854]
# 493  (39.688, 512.329]
# 96    (21.679, 39.688]
# 116    (-0.001, 7.854]

# %% [markdown]
# Find passengers with missing Age values.

# %%
df.loc[(df["Age"].isnull())]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          MORAN, MR. JAMES
# 17            18         1       2              WILLIAMS, MR. CHARLES EUGENE
# 19            20         1       3                   MASSELMANI, MRS. FATIMA
# 26            27         0       3                   EMIR, MR. FARRED CHEHAB
# 28            29         1       3             O'DWYER, MISS. ELLEN "NELLIE"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          RAZI, MR. RAIHED
# 863          864         0       3         SAGE, MISS. DOROTHY EDITH "DOLLY"
# 868          869         0       3               VAN MELKEBEKE, MR. PHILEMON
# 878          879         0       3                        LALEFF, MR. KRISTO
# 888          889         0       3  JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
#
#      Gender  Age  SibSp  Parch      Ticket     Fare Cabin Embarked  \
# 5      male  NaN      0      0      330877   8.4583   NaN        Q
# 17     male  NaN      0      0      244373  13.0000   NaN        S
# 19   female  NaN      0      0        2649   7.2250   NaN        C
# 26     male  NaN      0      0        2631   7.2250   NaN        C
# 28   female  NaN      0      0      330959   7.8792   NaN        Q
# ..      ...  ...    ...    ...         ...      ...   ...      ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S
# 868    male  NaN      0      0      345777   9.5000   NaN        S
# 878    male  NaN      0      0      349217   7.8958   NaN        S
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S
#
#             FareBucket
# 5        (7.854, 10.5]
# 17      (10.5, 21.679]
# 19     (-0.001, 7.854]
# 26     (-0.001, 7.854]
# 28       (7.854, 10.5]
# ..                 ...
# 859    (-0.001, 7.854]
# 863  (39.688, 512.329]
# 868      (7.854, 10.5]
# 878      (7.854, 10.5]
# 888   (21.679, 39.688]
#
# [177 rows x 13 columns]

# %% [markdown]
# Fill missing Age values with the mean age.

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender        Age  \
# 0                              BRAUND, MR. OWEN HARRIS    male  22.000000
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.000000
# 2                               HEIKKINEN, MISS. LAINA  female  26.000000
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.000000
# 4                             ALLEN, MR. WILLIAM HENRY    male  35.000000
# ..                                                 ...     ...        ...
# 886                              MONTVILA, REV. JUOZAS    male  27.000000
# 887                       GRAHAM, MISS. MARGARET EDITH  female  19.000000
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female  29.699118
# 889                              BEHR, MR. KARL HOWELL    male  26.000000
# 890                                DOOLEY, MR. PATRICK    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked         FareBucket
# 0        1      0         A/5 21171   7.2500   NaN        S    (-0.001, 7.854]
# 1        1      0          PC 17599  71.2833   C85        C  (39.688, 512.329]
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S      (7.854, 10.5]
# 3        1      0            113803  53.1000  C123        S  (39.688, 512.329]
# 4        0      0            373450   8.0500   NaN        S      (7.854, 10.5]
# ..     ...    ...               ...      ...   ...      ...                ...
# 886      0      0            211536  13.0000   NaN        S     (10.5, 21.679]
# 887      0      0            112053  30.0000   B42        S   (21.679, 39.688]
# 888      1      2        W./C. 6607  23.4500   NaN        S   (21.679, 39.688]
# 889      0      0            111369  30.0000  C148        C   (21.679, 39.688]
# 890      0      0            370376   7.7500   NaN        Q    (-0.001, 7.854]
#
# [891 rows x 13 columns]

# %% [markdown]
# Replace missing Embarked values with the mode.

# %%
df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender        Age  \
# 0                              BRAUND, MR. OWEN HARRIS    male  22.000000
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.000000
# 2                               HEIKKINEN, MISS. LAINA  female  26.000000
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.000000
# 4                             ALLEN, MR. WILLIAM HENRY    male  35.000000
# ..                                                 ...     ...        ...
# 886                              MONTVILA, REV. JUOZAS    male  27.000000
# 887                       GRAHAM, MISS. MARGARET EDITH  female  19.000000
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female  29.699118
# 889                              BEHR, MR. KARL HOWELL    male  26.000000
# 890                                DOOLEY, MR. PATRICK    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked         FareBucket
# 0        1      0         A/5 21171   7.2500   NaN        S    (-0.001, 7.854]
# 1        1      0          PC 17599  71.2833   C85        C  (39.688, 512.329]
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S      (7.854, 10.5]
# 3        1      0            113803  53.1000  C123        S  (39.688, 512.329]
# 4        0      0            373450   8.0500   NaN        S      (7.854, 10.5]
# ..     ...    ...               ...      ...   ...      ...                ...
# 886      0      0            211536  13.0000   NaN        S     (10.5, 21.679]
# 887      0      0            112053  30.0000   B42        S   (21.679, 39.688]
# 888      1      2        W./C. 6607  23.4500   NaN        S   (21.679, 39.688]
# 889      0      0            111369  30.0000  C148        C   (21.679, 39.688]
# 890      0      0            370376   7.7500   NaN        Q    (-0.001, 7.854]
#
# [891 rows x 13 columns]

# %% [markdown]
# How many passengers have SibSp > 2?

# %%
len(df.loc[(df['SibSp']>2)])
# Out:
# 46

# %% [markdown]
# Count passengers grouped by Embarked and Sex.

# %%
df.groupby("Embarked").count()
# Out:
#           PassengerId  Survived  Pclass  Name  Gender  Age  SibSp  Parch  \
# Embarked
# C                 168       168     168   168     168  168    168    168
# Q                  77        77      77    77      77   77     77     77
# S                 644       644     644   644     644  644    644    644
#
#           Ticket  Fare  Cabin  FareBucket
# Embarked
# C            168   168     69         168
# Q             77    77      4          77
# S            644   644    129         644

# %%
df.groupby("Sex").count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2402912637.py in <cell line: 0>()
# ----> 1 df.groupby("Sex").count()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'Sex'

# %%
result = df.groupby(['Embarked', 'Sex']).size()
result
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1094131637.py in <cell line: 0>()
# ----> 1 result = df.groupby(['Embarked', 'Sex']).size()
#       2 result
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'Sex'

# %% [markdown]
# Find min, max, mean fare for each class.

# %%
df.groupby("Pclass")["Fare"].describe()
# Out:
#         count       mean        std  min       25%      50%   75%       max
# Pclass
# 1       216.0  84.154687  78.380373  0.0  30.92395  60.2875  93.5  512.3292
# 2       184.0  20.662183  13.417399  0.0  13.00000  14.2500  26.0   73.5000
# 3       491.0  13.675550  11.778142  0.0   7.75000   8.0500  15.5   69.5500

# %%
df.groupby("Pclass")["Fare"].agg(['min','max','mean'])
# Out:
#         min       max       mean
# Pclass
# 1       0.0  512.3292  84.154687
# 2       0.0   73.5000  20.662183
# 3       0.0   69.5500  13.675550

# %% [markdown]
# Create a new column “FamilySize” = SibSp + Parch + 1.

# %%
df["FamilySize"] = df["SibSp"] + df["Parch"] + 1
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender        Age  \
# 0                              BRAUND, MR. OWEN HARRIS    male  22.000000
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.000000
# 2                               HEIKKINEN, MISS. LAINA  female  26.000000
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.000000
# 4                             ALLEN, MR. WILLIAM HENRY    male  35.000000
# ..                                                 ...     ...        ...
# 886                              MONTVILA, REV. JUOZAS    male  27.000000
# 887                       GRAHAM, MISS. MARGARET EDITH  female  19.000000
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female  29.699118
# 889                              BEHR, MR. KARL HOWELL    male  26.000000
# 890                                DOOLEY, MR. PATRICK    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 3        1      0            113803  53.1000  C123        S
# 4        0      0            373450   8.0500   NaN        S
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000   NaN        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
#             FareBucket  FamilySize
# 0      (-0.001, 7.854]           2
# 1    (39.688, 512.329]           2
# 2        (7.854, 10.5]           1
# 3    (39.688, 512.329]           2
# 4        (7.854, 10.5]           1
# ..                 ...         ...
# 886     (10.5, 21.679]           1
# 887   (21.679, 39.688]           1
# 888   (21.679, 39.688]           4
# 889   (21.679, 39.688]           1
# 890    (-0.001, 7.854]           1
#
# [891 rows x 14 columns]

# %% [markdown]
# Create a new column “IsChild” where Age < 18.

# %%
df['IsChild'] = df["Age"]<18
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender        Age  \
# 0                              BRAUND, MR. OWEN HARRIS    male  22.000000
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.000000
# 2                               HEIKKINEN, MISS. LAINA  female  26.000000
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.000000
# 4                             ALLEN, MR. WILLIAM HENRY    male  35.000000
# ..                                                 ...     ...        ...
# 886                              MONTVILA, REV. JUOZAS    male  27.000000
# 887                       GRAHAM, MISS. MARGARET EDITH  female  19.000000
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female  29.699118
# 889                              BEHR, MR. KARL HOWELL    male  26.000000
# 890                                DOOLEY, MR. PATRICK    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 3        1      0            113803  53.1000  C123        S
# 4        0      0            373450   8.0500   NaN        S
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000   NaN        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
#             FareBucket  FamilySize  IsChild
# 0      (-0.001, 7.854]           2    False
# 1    (39.688, 512.329]           2    False
# 2        (7.854, 10.5]           1    False
# 3    (39.688, 512.329]           2    False
# 4        (7.854, 10.5]           1    False
# ..                 ...         ...      ...
# 886     (10.5, 21.679]           1    False
# 887   (21.679, 39.688]           1    False
# 888   (21.679, 39.688]           4    False
# 889   (21.679, 39.688]           1    False
# 890    (-0.001, 7.854]           1    False
#
# [891 rows x 15 columns]

# %% [markdown]
# Count how many children survived.

# %%
len(df.loc[(df["IsChild"]==True)&(df["Survived"]==1)])
# Out:
# 61

# %%
df.loc[(df["IsChild"]==True)&(df["Survived"]==1)].shape[0]
# Out:
# 61

# %% [markdown]
# Show survival rate per Pclass.

# %%
df.groupby("Pclass")["Survived"].mean()*100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %% [markdown]
# Show survival rate per Sex.

# %%
df.groupby("Sex")["Survived"].mean()*100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1289586624.py in <cell line: 0>()
# ----> 1 df.groupby("Sex")["Survived"].mean()*100
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'Sex'

# %% [markdown]
# Which Ticket occurs most often?

# %%
df.value_counts("Ticket")
# Out:
# Ticket
# 1601        7
# CA. 2343    7
# 347082      7
# CA 2144     6
# 3101295     6
#            ..
# 112052      1
# 112050      1
# 111428      1
# 111427      1
# 111426      1
# Name: count, Length: 681, dtype: int64

# %%
df['Ticket'].mode()[0]
# Out:
# '1601'

# %%
df['Ticket'].mode()
# Out:
# 0        1601
# 1      347082
# 2    CA. 2343
# Name: Ticket, dtype: object

# %% [markdown]
# Which Cabin letter appears the most (use str[0])?

# %%
df["Cabin"].str[0].mode()
# Out:
# 0    C
# Name: Cabin, dtype: object

# %% [markdown]
# How many passengers have Fare = 0?

# %%
len(df.loc[(df["Fare"]==0)])
# Out:
# 15

# %%
df.loc[(df["Fare"]==0)]
# Out:
#      PassengerId  Survived  Pclass                              Name Gender  \
# 179          180         0       3               LEONARD, MR. LIONEL   male
# 263          264         0       1             HARRISON, MR. WILLIAM   male
# 271          272         1       3      TORNQUIST, MR. WILLIAM HENRY   male
# 277          278         0       2       PARKES, MR. FRANCIS "FRANK"   male
# 302          303         0       3   JOHNSON, MR. WILLIAM CAHOONE JR   male
# 413          414         0       2    CUNNINGHAM, MR. ALFRED FLEMING   male
# 466          467         0       2             CAMPBELL, MR. WILLIAM   male
# 481          482         0       2  FROST, MR. ANTHONY WOOD "ARCHIE"   male
# 597          598         0       3               JOHNSON, MR. ALFRED   male
# 633          634         0       1     PARR, MR. WILLIAM HENRY MARSH   male
# 674          675         0       2        WATSON, MR. ENNIS HASTINGS   male
# 732          733         0       2              KNIGHT, MR. ROBERT J   male
# 806          807         0       1            ANDREWS, MR. THOMAS JR   male
# 815          816         0       1                  FRY, MR. RICHARD   male
# 822          823         0       1   REUCHLIN, JONKHEER. JOHN GEORGE   male
#
#            Age  SibSp  Parch  Ticket  Fare Cabin Embarked       FareBucket  \
# 179  36.000000      0      0    LINE   0.0   NaN        S  (-0.001, 7.854]
# 263  40.000000      0      0  112059   0.0   B94        S  (-0.001, 7.854]
# 271  25.000000      0      0    LINE   0.0   NaN        S  (-0.001, 7.854]
# 277  29.699118      0      0  239853   0.0   NaN        S  (-0.001, 7.854]
# 302  19.000000      0      0    LINE   0.0   NaN        S  (-0.001, 7.854]
# 413  29.699118      0      0  239853   0.0   NaN        S  (-0.001, 7.854]
# 466  29.699118      0      0  239853   0.0   NaN        S  (-0.001, 7.854]
# 481  29.699118      0      0  239854   0.0   NaN        S  (-0.001, 7.854]
# 597  49.000000      0      0    LINE   0.0   NaN        S  (-0.001, 7.854]
# 633  29.699118      0      0  112052   0.0   NaN        S  (-0.001, 7.854]
# 674  29.699118      0      0  239856   0.0   NaN        S  (-0.001, 7.854]
# 732  29.699118      0      0  239855   0.0   NaN        S  (-0.001, 7.854]
# 806  39.000000      0      0  112050   0.0   A36        S  (-0.001, 7.854]
# 815  29.699118      0      0  112058   0.0  B102        S  (-0.001, 7.854]
# 822  38.000000      0      0   19972   0.0   NaN        S  (-0.001, 7.854]
#
#      FamilySize  IsChild
# 179           1    False
# 263           1    False
# 271           1    False
# 277           1    False
# 302           1    False
# 413           1    False
# 466           1    False
# 481           1    False
# 597           1    False
# 633           1    False
# 674           1    False
# 732           1    False
# 806           1    False
# 815           1    False
# 822           1    False

# %% [markdown]
# # LEVEL 3 — DIFFICULT (41–60)

# %% [markdown]
# Use groupby to compute average Age per Sex per Pclass.

# %%
df.groupby(["Sex","Pclass"])["Age"].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2632043826.py in <cell line: 0>()
# ----> 1 df.groupby(["Sex","Pclass"])["Age"].mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'Sex'

# %% [markdown]
# Find the passenger who paid the highest fare.

# %%
df.loc[(df["Fare"]==df["Fare"].max())]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    WARD, MISS. ANNA
# 679          680         1       1  CARDEZA, MR. THOMAS DRAKE MARTINEZ
# 737          738         1       1              LESURER, MR. GUSTAVE J
#
#      Gender   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#             FareBucket  FamilySize  IsChild
# 258  (39.688, 512.329]           1    False
# 679  (39.688, 512.329]           2    False
# 737  (39.688, 512.329]           1    False

# %%
df["Fare"].max()
# Out:
# 512.3292

# %%
df[(df["Fare"]==df["Fare"].max())]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    WARD, MISS. ANNA
# 679          680         1       1  CARDEZA, MR. THOMAS DRAKE MARTINEZ
# 737          738         1       1              LESURER, MR. GUSTAVE J
#
#      Gender   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#             FareBucket  FamilySize  IsChild
# 258  (39.688, 512.329]           1    False
# 679  (39.688, 512.329]           2    False
# 737  (39.688, 512.329]           1    False

# %% [markdown]
# Find rows where Name contains “Mrs”.

# %%
df[df["Name"].str.contains("Mrs",na = False)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Gender, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, FareBucket, FamilySize, IsChild]
# Index: []

# %% [markdown]
# Extract honorific title (Mr, Mrs, Miss, etc.) from Name.

# %%
df['Title'] = df['Name'].str.extract(r',\s*([^\.]+)\.')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender        Age  \
# 0                              BRAUND, MR. OWEN HARRIS    male  22.000000
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.000000
# 2                               HEIKKINEN, MISS. LAINA  female  26.000000
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.000000
# 4                             ALLEN, MR. WILLIAM HENRY    male  35.000000
# ..                                                 ...     ...        ...
# 886                              MONTVILA, REV. JUOZAS    male  27.000000
# 887                       GRAHAM, MISS. MARGARET EDITH  female  19.000000
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female  29.699118
# 889                              BEHR, MR. KARL HOWELL    male  26.000000
# 890                                DOOLEY, MR. PATRICK    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 3        1      0            113803  53.1000  C123        S
# 4        0      0            373450   8.0500   NaN        S
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000   NaN        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
#             FareBucket  FamilySize  IsChild Title
# 0      (-0.001, 7.854]           2    False    MR
# 1    (39.688, 512.329]           2    False   MRS
# 2        (7.854, 10.5]           1    False  MISS
# 3    (39.688, 512.329]           2    False   MRS
# 4        (7.854, 10.5]           1    False    MR
# ..                 ...         ...      ...   ...
# 886     (10.5, 21.679]           1    False   REV
# 887   (21.679, 39.688]           1    False  MISS
# 888   (21.679, 39.688]           4    False  MISS
# 889   (21.679, 39.688]           1    False    MR
# 890    (-0.001, 7.854]           1    False    MR
#
# [891 rows x 16 columns]

# %% [markdown]
# Count survival rate for each title.

# %%
df.groupby("Title")["Survived"].mean()*100
# Out:
# Title
# CAPT              0.000000
# COL              50.000000
# DON               0.000000
# DR               42.857143
# JONKHEER          0.000000
# LADY            100.000000
# MAJOR            50.000000
# MASTER           57.500000
# MISS             69.780220
# MLLE            100.000000
# MME             100.000000
# MR               15.667311
# MRS              79.200000
# MS              100.000000
# REV               0.000000
# SIR             100.000000
# THE COUNTESS    100.000000
# Name: Survived, dtype: float64

# %% [markdown]
# Find correlation between Age, Fare, Pclass, Survived.

# %%
df[['Age','Fare','Pclass','Survived']].corr()
# Out:
#                Age      Fare    Pclass  Survived
# Age       1.000000  0.091566 -0.331339 -0.069809
# Fare      0.091566  1.000000 -0.549500  0.257307
# Pclass   -0.331339 -0.549500  1.000000 -0.338481
# Survived -0.069809  0.257307 -0.338481  1.000000

# %% [markdown]
# Normalize the Fare column (0–1 scale).

# %%
df['Fare_norm'] = (df['Fare'] - df['Fare'].min()) / (df['Fare'].max() - df['Fare'].min())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender        Age  \
# 0                              BRAUND, MR. OWEN HARRIS    male  22.000000
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.000000
# 2                               HEIKKINEN, MISS. LAINA  female  26.000000
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.000000
# 4                             ALLEN, MR. WILLIAM HENRY    male  35.000000
# ..                                                 ...     ...        ...
# 886                              MONTVILA, REV. JUOZAS    male  27.000000
# 887                       GRAHAM, MISS. MARGARET EDITH  female  19.000000
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female  29.699118
# 889                              BEHR, MR. KARL HOWELL    male  26.000000
# 890                                DOOLEY, MR. PATRICK    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 3        1      0            113803  53.1000  C123        S
# 4        0      0            373450   8.0500   NaN        S
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000   NaN        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
#             FareBucket  FamilySize  IsChild Title  Fare_norm
# 0      (-0.001, 7.854]           2    False    MR   0.014151
# 1    (39.688, 512.329]           2    False   MRS   0.139136
# 2        (7.854, 10.5]           1    False  MISS   0.015469
# 3    (39.688, 512.329]           2    False   MRS   0.103644
# 4        (7.854, 10.5]           1    False    MR   0.015713
# ..                 ...         ...      ...   ...        ...
# 886     (10.5, 21.679]           1    False   REV   0.025374
# 887   (21.679, 39.688]           1    False  MISS   0.058556
# 888   (21.679, 39.688]           4    False  MISS   0.045771
# 889   (21.679, 39.688]           1    False    MR   0.058556
# 890    (-0.001, 7.854]           1    False    MR   0.015127
#
# [891 rows x 17 columns]

# %% [markdown]
# Bin Age into categories: Child/Adult/Senior.

# %%
df["Age_Groups"] = df["Age"].apply(lambda x:"Child" if x <=18 else("Adult" if x<=60 else("Senior")))
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender        Age  \
# 0                              BRAUND, MR. OWEN HARRIS    male  22.000000
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.000000
# 2                               HEIKKINEN, MISS. LAINA  female  26.000000
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.000000
# 4                             ALLEN, MR. WILLIAM HENRY    male  35.000000
# ..                                                 ...     ...        ...
# 886                              MONTVILA, REV. JUOZAS    male  27.000000
# 887                       GRAHAM, MISS. MARGARET EDITH  female  19.000000
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female  29.699118
# 889                              BEHR, MR. KARL HOWELL    male  26.000000
# 890                                DOOLEY, MR. PATRICK    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 3        1      0            113803  53.1000  C123        S
# 4        0      0            373450   8.0500   NaN        S
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000   NaN        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
#             FareBucket  FamilySize  IsChild Title  Fare_norm Age_Groups
# 0      (-0.001, 7.854]           2    False    MR   0.014151      Adult
# 1    (39.688, 512.329]           2    False   MRS   0.139136      Adult
# 2        (7.854, 10.5]           1    False  MISS   0.015469      Adult
# 3    (39.688, 512.329]           2    False   MRS   0.103644      Adult
# 4        (7.854, 10.5]           1    False    MR   0.015713      Adult
# ..                 ...         ...      ...   ...        ...        ...
# 886     (10.5, 21.679]           1    False   REV   0.025374      Adult
# 887   (21.679, 39.688]           1    False  MISS   0.058556      Adult
# 888   (21.679, 39.688]           4    False  MISS   0.045771      Adult
# 889   (21.679, 39.688]           1    False    MR   0.058556      Adult
# 890    (-0.001, 7.854]           1    False    MR   0.015127      Adult
#
# [891 rows x 18 columns]

# %% [markdown]
# For each Embarked port, find the top 3 highest fares.

# %%
df.groupby('Embarked')['Fare'].nlargest(3)
# Out:
# Embarked
# C         258    512.3292
#           679    512.3292
#           737    512.3292
# Q         245     90.0000
#           412     90.0000
#           16      29.1250
# S         27     263.0000
#           88     263.0000
#           341    263.0000
# Name: Fare, dtype: float64

# %% [markdown]
# Find the name of the youngest surviving female.

# %%
df.loc[(df["Sex"]=="female")&(df["Survived"]==1)].sort_values("Age").iloc[0]["Name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sex'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3337473680.py in <cell line: 0>()
# ----> 1 df.loc[(df["Sex"]=="female")&(df["Survived"]==1)].sort_values("Age").iloc[0]["Name"]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Sex'

# %%
df[df['Survived'] == 1].loc[df['Age'].idxmin()]['Name']
# Out:
# 'THOMAS, MASTER. ASSAD ALEXANDER'

# %% [markdown]
# Count how many passengers have the same last name.

# %%
df['Last'] = df['Name'].str.split(',').str[0]
df['Last'].value_counts()
# Out:
# Last
# ANDERSSON    9
# SAGE         7
# SKOOG        6
# PANULA       6
# CARTER       6
#             ..
# NYSVEEN      1
# YOUNG        1
# SLAYTER      1
# DANOFF       1
# HAAS         1
# Name: count, Length: 667, dtype: int64

# %% [markdown]
# Identify duplicate Ticket numbers.

# %%
df[df["Ticket"].duplicated(keep=False)]
# Out:
#      PassengerId  Survived  Pclass  \
# 3              4         1       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# ..           ...       ...     ...
# 876          877         0       3
# 879          880         1       1
# 880          881         1       2
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name  Gender        Age  \
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.000000
# 7                       PALSSON, MASTER. GOSTA LEONARD    male   2.000000
# 8    JOHNSON, MRS. OSCAR W (ELISABETH VILHELMINA BERG)  female  27.000000
# 9                  NASSER, MRS. NICHOLAS (ADELE ACHEM)  female  14.000000
# 10                     SANDSTROM, MISS. MARGUERITE RUT  female   4.000000
# ..                                                 ...     ...        ...
# 876                      GUSTAFSSON, MR. ALFRED OSSIAN    male  20.000000
# 879      POTTER, MRS. THOMAS JR (LILY ALEXENIA WILSON)  female  56.000000
# 880       SHELLEY, MRS. WILLIAM (IMANITA PARRISH HALL)  female  25.000000
# 885               RICE, MRS. WILLIAM (MARGARET NORTON)  female  39.000000
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female  29.699118
#
#      SibSp  Parch      Ticket     Fare Cabin Embarked         FareBucket  \
# 3        1      0      113803  53.1000  C123        S  (39.688, 512.329]
# 7        3      1      349909  21.0750   NaN        S     (10.5, 21.679]
# 8        0      2      347742  11.1333   NaN        S     (10.5, 21.679]
# 9        1      0      237736  30.0708   NaN        C   (21.679, 39.688]
# 10       1      1     PP 9549  16.7000    G6        S     (10.5, 21.679]
# ..     ...    ...         ...      ...   ...      ...                ...
# 876      0      0        7534   9.8458   NaN        S      (7.854, 10.5]
# 879      0      1       11767  83.1583   C50        C  (39.688, 512.329]
# 880      0      1      230433  26.0000   NaN        S   (21.679, 39.688]
# 885      0      5      382652  29.1250   NaN        Q   (21.679, 39.688]
# 888      1      2  W./C. 6607  23.4500   NaN        S   (21.679, 39.688]
#
#      FamilySize  IsChild   Title  Fare_norm Age_Groups        Last
# 3             2    False     MRS   0.103644      Adult    FUTRELLE
# 7             5     True  MASTER   0.041136      Child     PALSSON
# 8             3    False     MRS   0.021731      Adult     JOHNSON
# 9             2     True     MRS   0.058694      Child      NASSER
# 10            3     True    MISS   0.032596      Child   SANDSTROM
# ..          ...      ...     ...        ...        ...         ...
# 876           1    False      MR   0.019218      Adult  GUSTAFSSON
# 879           2    False     MRS   0.162314      Adult      POTTER
# 880           2    False     MRS   0.050749      Adult     SHELLEY
# 885           6    False     MRS   0.056848      Adult        RICE
# 888           4    False    MISS   0.045771      Adult    JOHNSTON
#
# [344 rows x 19 columns]

# %% [markdown]
# Find average family size per Pclass.

# %%
df.groupby("Pclass")["FamilySize"].mean()
# Out:
# Pclass
# 1    1.773148
# 2    1.782609
# 3    2.008147
# Name: FamilySize, dtype: float64

# %% [markdown]
# Create a column “IsAlone” (FamilySize == 1).

# %%
df["IsAlone"] = (df["FamilySize"]==1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender        Age  \
# 0                              BRAUND, MR. OWEN HARRIS    male  22.000000
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.000000
# 2                               HEIKKINEN, MISS. LAINA  female  26.000000
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.000000
# 4                             ALLEN, MR. WILLIAM HENRY    male  35.000000
# ..                                                 ...     ...        ...
# 886                              MONTVILA, REV. JUOZAS    male  27.000000
# 887                       GRAHAM, MISS. MARGARET EDITH  female  19.000000
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female  29.699118
# 889                              BEHR, MR. KARL HOWELL    male  26.000000
# 890                                DOOLEY, MR. PATRICK    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 3        1      0            113803  53.1000  C123        S
# 4        0      0            373450   8.0500   NaN        S
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000   NaN        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
#             FareBucket  FamilySize  IsChild Title  Fare_norm Age_Groups  \
# 0      (-0.001, 7.854]           2    False    MR   0.014151      Adult
# 1    (39.688, 512.329]           2    False   MRS   0.139136      Adult
# 2        (7.854, 10.5]           1    False  MISS   0.015469      Adult
# 3    (39.688, 512.329]           2    False   MRS   0.103644      Adult
# 4        (7.854, 10.5]           1    False    MR   0.015713      Adult
# ..                 ...         ...      ...   ...        ...        ...
# 886     (10.5, 21.679]           1    False   REV   0.025374      Adult
# 887   (21.679, 39.688]           1    False  MISS   0.058556      Adult
# 888   (21.679, 39.688]           4    False  MISS   0.045771      Adult
# 889   (21.679, 39.688]           1    False    MR   0.058556      Adult
# 890    (-0.001, 7.854]           1    False    MR   0.015127      Adult
#
#           Last  IsAlone
# 0       BRAUND    False
# 1      CUMINGS    False
# 2    HEIKKINEN     True
# 3     FUTRELLE    False
# 4        ALLEN     True
# ..         ...      ...
# 886   MONTVILA     True
# 887     GRAHAM     True
# 888   JOHNSTON    False
# 889       BEHR     True
# 890     DOOLEY     True
#
# [891 rows x 20 columns]

# %% [markdown]
# Survival chance comparison: Alone vs Not alone.

# %%
df.groupby("IsAlone")["Survived"].mean()
# Out:
# IsAlone
# False    0.505650
# True     0.303538
# Name: Survived, dtype: float64

# %% [markdown]
# Find the fare per person by dividing Fare / FamilySize.

# %%
df["FarePerPerson"] = df["Fare"]/df["FamilySize"]
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender        Age  \
# 0                              BRAUND, MR. OWEN HARRIS    male  22.000000
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.000000
# 2                               HEIKKINEN, MISS. LAINA  female  26.000000
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.000000
# 4                             ALLEN, MR. WILLIAM HENRY    male  35.000000
# ..                                                 ...     ...        ...
# 886                              MONTVILA, REV. JUOZAS    male  27.000000
# 887                       GRAHAM, MISS. MARGARET EDITH  female  19.000000
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female  29.699118
# 889                              BEHR, MR. KARL HOWELL    male  26.000000
# 890                                DOOLEY, MR. PATRICK    male  32.000000
#
#      SibSp  Parch            Ticket     Fare  ... Embarked         FareBucket  \
# 0        1      0         A/5 21171   7.2500  ...        S    (-0.001, 7.854]
# 1        1      0          PC 17599  71.2833  ...        C  (39.688, 512.329]
# 2        0      0  STON/O2. 3101282   7.9250  ...        S      (7.854, 10.5]
# 3        1      0            113803  53.1000  ...        S  (39.688, 512.329]
# 4        0      0            373450   8.0500  ...        S      (7.854, 10.5]
# ..     ...    ...               ...      ...  ...      ...                ...
# 886      0      0            211536  13.0000  ...        S     (10.5, 21.679]
# 887      0      0            112053  30.0000  ...        S   (21.679, 39.688]
# 888      1      2        W./C. 6607  23.4500  ...        S   (21.679, 39.688]
# 889      0      0            111369  30.0000  ...        C   (21.679, 39.688]
# 890      0      0            370376   7.7500  ...        Q    (-0.001, 7.854]
#
#     FamilySize  IsChild  Title Fare_norm  Age_Groups       Last IsAlone  \
# 0            2    False     MR  0.014151       Adult     BRAUND   False
# 1            2    False    MRS  0.139136       Adult    CUMINGS   False
# 2            1    False   MISS  0.015469       Adult  HEIKKINEN    True
# 3            2    False    MRS  0.103644       Adult   FUTRELLE   False
# 4            1    False     MR  0.015713       Adult      ALLEN    True
# ..         ...      ...    ...       ...         ...        ...     ...
# 886          1    False    REV  0.025374       Adult   MONTVILA    True
# 887          1    False   MISS  0.058556       Adult     GRAHAM    True
# 888          4    False   MISS  0.045771       Adult   JOHNSTON   False
# 889          1    False     MR  0.058556       Adult       BEHR    True
# 890          1    False     MR  0.015127       Adult     DOOLEY    True
#
#      FarePerPerson
# 0          3.62500
# 1         35.64165
# 2          7.92500
# 3         26.55000
# 4          8.05000
# ..             ...
# 886       13.00000
# 887       30.00000
# 888        5.86250
# 889       30.00000
# 890        7.75000
#
# [891 rows x 21 columns]

# %% [markdown]
# Get the passenger with the longest name.

# %%
df.loc[df["Name"].str.len().idxmax(), "Name"]
# Out:
# 'PENASCO Y CASTELLANA, MRS. VICTOR DE SATODE (MARIA JOSEFA PEREZ DE SOTO Y VALLEJO)'

# %% [markdown]
# Compute median age per Pclass and fill missing ages class-wise.

# %%
df.groupby("Pclass")["Age"].median()
# Out:
# Pclass
# 1    35.000000
# 2    29.699118
# 3    29.699118
# Name: Age, dtype: float64

# %% [markdown]
# Compare male vs female survival rate within each class.

# %%
df.groupby(["Sex","Pclass"])["Survived"].mean()*100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1217152862.py in <cell line: 0>()
# ----> 1 df.groupby(["Sex","Pclass"])["Survived"].mean()*100
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'Sex'

# %% [markdown]
# Determine if fare distribution is right-skewed or left-skewed.

# %%
temp = df["Fare"].skew()
print(temp)
# Out:
# 4.787316519674893

# %% [markdown]
# # 🔥 LEVEL 4 — HARD (61–80)

# %% [markdown]
# Find the age gap between the oldest and youngest passenger per class.

# %%
df.groupby("Pclass")["Age"].agg(["min","max",lambda x : x.max()-x.min()])
# Out:
#          min   max  <lambda_0>
# Pclass
# 1       0.92  80.0       79.08
# 2       0.67  70.0       69.33
# 3       0.42  74.0       73.58

# %% [markdown]
# Create a pivot table showing survival by Sex and Pclass.

# %%
df.pivot_table(values="Survived",index="Sex",columns="Pclass",aggfunc="mean")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2656123872.py in <cell line: 0>()
# ----> 1 df.pivot_table(values="Survived",index="Sex",columns="Pclass",aggfunc="mean")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9507         from pandas.core.reshape.pivot import pivot_table
#    9508
# -> 9509         return pivot_table(
#    9510             self,
#    9511             values=values,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     100         return table.__finalize__(data, method="pivot_table")
#     101
# --> 102     table = __internal_pivot_table(
#     103         data,
#     104         values,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/pivot.py in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     170
#     171     observed_bool = False if observed is lib.no_default else observed
# --> 172     grouped = data.groupby(keys, observed=observed_bool, sort=sort, dropna=dropna)
#     173     if observed is lib.no_default and any(
#     174         ping._passed_categorical for ping in grouped._grouper.groupings
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'Sex'

# %% [markdown]
# Identify passengers traveling with siblings AND parents.

# %%
df[(df["SibSp"]>0)&(df["Parch"]>0)]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 10            11         1       3
# 13            14         0       3
# 16            17         0       3
# 24            25         0       3
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 869          870         1       3
# 871          872         1       1
# 888          889         0       3
#
#                                                  Name  Gender        Age  \
# 7                      PALSSON, MASTER. GOSTA LEONARD    male   2.000000
# 10                    SANDSTROM, MISS. MARGUERITE RUT  female   4.000000
# 13                        ANDERSSON, MR. ANDERS JOHAN    male  39.000000
# 16                               RICE, MASTER. EUGENE    male   2.000000
# 24                      PALSSON, MISS. TORBORG DANIRA  female   8.000000
# ..                                                ...     ...        ...
# 856        WICK, MRS. GEORGE DENNICK (MARY HITCHCOCK)  female  45.000000
# 863                 SAGE, MISS. DOROTHY EDITH "DOLLY"  female  29.699118
# 869                   JOHNSON, MASTER. HAROLD THEODOR    male   4.000000
# 871  BECKWITH, MRS. RICHARD LEONARD (SALLIE MONYPENY)  female  47.000000
# 888          JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female  29.699118
#
#      SibSp  Parch      Ticket      Fare  ... Embarked         FareBucket  \
# 7        3      1      349909   21.0750  ...        S     (10.5, 21.679]
# 10       1      1     PP 9549   16.7000  ...        S     (10.5, 21.679]
# 13       1      5      347082   31.2750  ...        S   (21.679, 39.688]
# 16       4      1      382652   29.1250  ...        Q   (21.679, 39.688]
# 24       3      1      349909   21.0750  ...        S     (10.5, 21.679]
# ..     ...    ...         ...       ...  ...      ...                ...
# 856      1      1       36928  164.8667  ...        S  (39.688, 512.329]
# 863      8      2    CA. 2343   69.5500  ...        S  (39.688, 512.329]
# 869      1      1      347742   11.1333  ...        S     (10.5, 21.679]
# 871      1      1       11751   52.5542  ...        S  (39.688, 512.329]
# 888      1      2  W./C. 6607   23.4500  ...        S   (21.679, 39.688]
#
#     FamilySize  IsChild   Title Fare_norm  Age_Groups       Last IsAlone  \
# 7            5     True  MASTER  0.041136       Child    PALSSON   False
# 10           3     True    MISS  0.032596       Child  SANDSTROM   False
# 13           7    False      MR  0.061045       Adult  ANDERSSON   False
# 16           6     True  MASTER  0.056848       Child       RICE   False
# 24           5     True    MISS  0.041136       Child    PALSSON   False
# ..         ...      ...     ...       ...         ...        ...     ...
# 856          3    False     MRS  0.321798       Adult       WICK   False
# 863         11    False    MISS  0.135753       Adult       SAGE   False
# 869          3     True  MASTER  0.021731       Child    JOHNSON   False
# 871          3    False     MRS  0.102579       Adult   BECKWITH   False
# 888          4    False    MISS  0.045771       Adult   JOHNSTON   False
#
#      FarePerPerson
# 7         4.215000
# 10        5.566667
# 13        4.467857
# 16        4.854167
# 24        4.215000
# ..             ...
# 856      54.955567
# 863       6.322727
# 869       3.711100
# 871      17.518067
# 888       5.862500
#
# [142 rows x 21 columns]

# %% [markdown]
# Which Embarked port had the highest survival percentage?

# %%
df.groupby("Embarked")["Survived"].mean()*100
# Out:
# Embarked
# C    55.357143
# Q    38.961039
# S    33.695652
# Name: Survived, dtype: float64

# %% [markdown]
# Create a new column “FareBucket” using qcut into 5 bins.

# %%
df["FareBucket"] = pd.qcut(df["Fare"], q=5)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender        Age  \
# 0                              BRAUND, MR. OWEN HARRIS    male  22.000000
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.000000
# 2                               HEIKKINEN, MISS. LAINA  female  26.000000
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.000000
# 4                             ALLEN, MR. WILLIAM HENRY    male  35.000000
# ..                                                 ...     ...        ...
# 886                              MONTVILA, REV. JUOZAS    male  27.000000
# 887                       GRAHAM, MISS. MARGARET EDITH  female  19.000000
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female  29.699118
# 889                              BEHR, MR. KARL HOWELL    male  26.000000
# 890                                DOOLEY, MR. PATRICK    male  32.000000
#
#      SibSp  Parch            Ticket     Fare  ... Embarked         FareBucket  \
# 0        1      0         A/5 21171   7.2500  ...        S    (-0.001, 7.854]
# 1        1      0          PC 17599  71.2833  ...        C  (39.688, 512.329]
# 2        0      0  STON/O2. 3101282   7.9250  ...        S      (7.854, 10.5]
# 3        1      0            113803  53.1000  ...        S  (39.688, 512.329]
# 4        0      0            373450   8.0500  ...        S      (7.854, 10.5]
# ..     ...    ...               ...      ...  ...      ...                ...
# 886      0      0            211536  13.0000  ...        S     (10.5, 21.679]
# 887      0      0            112053  30.0000  ...        S   (21.679, 39.688]
# 888      1      2        W./C. 6607  23.4500  ...        S   (21.679, 39.688]
# 889      0      0            111369  30.0000  ...        C   (21.679, 39.688]
# 890      0      0            370376   7.7500  ...        Q    (-0.001, 7.854]
#
#     FamilySize  IsChild  Title Fare_norm  Age_Groups       Last IsAlone  \
# 0            2    False     MR  0.014151       Adult     BRAUND   False
# 1            2    False    MRS  0.139136       Adult    CUMINGS   False
# 2            1    False   MISS  0.015469       Adult  HEIKKINEN    True
# 3            2    False    MRS  0.103644       Adult   FUTRELLE   False
# 4            1    False     MR  0.015713       Adult      ALLEN    True
# ..         ...      ...    ...       ...         ...        ...     ...
# 886          1    False    REV  0.025374       Adult   MONTVILA    True
# 887          1    False   MISS  0.058556       Adult     GRAHAM    True
# 888          4    False   MISS  0.045771       Adult   JOHNSTON   False
# 889          1    False     MR  0.058556       Adult       BEHR    True
# 890          1    False     MR  0.015127       Adult     DOOLEY    True
#
#      FarePerPerson
# 0          3.62500
# 1         35.64165
# 2          7.92500
# 3         26.55000
# 4          8.05000
# ..             ...
# 886       13.00000
# 887       30.00000
# 888        5.86250
# 889       30.00000
# 890        7.75000
#
# [891 rows x 21 columns]

# %% [markdown]
# Compare survival rate across FareBuckets.

# %%
df.groupby("FareBucket")["Survived"].mean()
# Out:
# /tmp/ipython-input-3488122341.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("FareBucket")["Survived"].mean()
# FareBucket
# (-0.001, 7.854]      0.217877
# (7.854, 10.5]        0.201087
# (10.5, 21.679]       0.424419
# (21.679, 39.688]     0.444444
# (39.688, 512.329]    0.642045
# Name: Survived, dtype: float64

# %%
df.groupby("Pclass")["Fare"].var()
# Out:
# Pclass
# 1    6143.482816
# 2     180.026589
# 3     138.724622
# Name: Fare, dtype: float64

# %% [markdown]
# Use apply to format Name into uppercase.

# %%
df["Name"] = df["Name"].apply(lambda x: x.upper())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender        Age  \
# 0                              BRAUND, MR. OWEN HARRIS    male  22.000000
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.000000
# 2                               HEIKKINEN, MISS. LAINA  female  26.000000
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.000000
# 4                             ALLEN, MR. WILLIAM HENRY    male  35.000000
# ..                                                 ...     ...        ...
# 886                              MONTVILA, REV. JUOZAS    male  27.000000
# 887                       GRAHAM, MISS. MARGARET EDITH  female  19.000000
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female  29.699118
# 889                              BEHR, MR. KARL HOWELL    male  26.000000
# 890                                DOOLEY, MR. PATRICK    male  32.000000
#
#      SibSp  Parch            Ticket     Fare  ... Embarked         FareBucket  \
# 0        1      0         A/5 21171   7.2500  ...        S    (-0.001, 7.854]
# 1        1      0          PC 17599  71.2833  ...        C  (39.688, 512.329]
# 2        0      0  STON/O2. 3101282   7.9250  ...        S      (7.854, 10.5]
# 3        1      0            113803  53.1000  ...        S  (39.688, 512.329]
# 4        0      0            373450   8.0500  ...        S      (7.854, 10.5]
# ..     ...    ...               ...      ...  ...      ...                ...
# 886      0      0            211536  13.0000  ...        S     (10.5, 21.679]
# 887      0      0            112053  30.0000  ...        S   (21.679, 39.688]
# 888      1      2        W./C. 6607  23.4500  ...        S   (21.679, 39.688]
# 889      0      0            111369  30.0000  ...        C   (21.679, 39.688]
# 890      0      0            370376   7.7500  ...        Q    (-0.001, 7.854]
#
#     FamilySize  IsChild  Title Fare_norm  Age_Groups       Last IsAlone  \
# 0            2    False     MR  0.014151       Adult     BRAUND   False
# 1            2    False    MRS  0.139136       Adult    CUMINGS   False
# 2            1    False   MISS  0.015469       Adult  HEIKKINEN    True
# 3            2    False    MRS  0.103644       Adult   FUTRELLE   False
# 4            1    False     MR  0.015713       Adult      ALLEN    True
# ..         ...      ...    ...       ...         ...        ...     ...
# 886          1    False    REV  0.025374       Adult   MONTVILA    True
# 887          1    False   MISS  0.058556       Adult     GRAHAM    True
# 888          4    False   MISS  0.045771       Adult   JOHNSTON   False
# 889          1    False     MR  0.058556       Adult       BEHR    True
# 890          1    False     MR  0.015127       Adult     DOOLEY    True
#
#      FarePerPerson
# 0          3.62500
# 1         35.64165
# 2          7.92500
# 3         26.55000
# 4          8.05000
# ..             ...
# 886       13.00000
# 887       30.00000
# 888        5.86250
# 889       30.00000
# 890        7.75000
#
# [891 rows x 21 columns]

# %% [markdown]
# Group passengers by Cabin deck (first letter).

# %%
df.groupby(df["Cabin"].str[0]).size()
# Out:
# Cabin
# A    15
# B    47
# C    59
# D    33
# E    32
# F    13
# G     4
# T     1
# dtype: int64

# %% [markdown]
# Find average survivor age per cabin deck.

# %%
df.groupby(df["Cabin"].str[0]).apply(lambda x: x[x["Survived"] == 1]["Age"].mean())
# Out:
# Cabin
# A    43.571429
# B    31.591403
# C    33.697588
# D    37.775929
# E    32.704093
# F    15.837390
# G    14.000000
# T          NaN
# dtype: float64

# %% [markdown]
# Determine if high-fare passengers survived more often.

# %%
temp = df[df["Fare"] >= df["Fare"].mean()]
intb  = temp["Survived"].mean()*100
print(intb)
# Out:
# 59.71563981042654

# %% [markdown]
# Calculate survival rate per family size.
#
# Identify which family size is most likely to survive.

# %%
df.groupby("FamilySize")["Survived"].mean()
# Out:
# FamilySize
# 1     0.303538
# 2     0.552795
# 3     0.578431
# 4     0.724138
# 5     0.200000
# 6     0.136364
# 7     0.333333
# 8     0.000000
# 11    0.000000
# Name: Survived, dtype: float64

# %%
df.groupby("FamilySize")["Survived"].mean().idxmax()
# Out:
# np.int64(4)

# %%
temp = df.sort_values("PassengerId")
temp["CumulativeSum"] = temp["Fare"].cumsum()
temp
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender        Age  \
# 0                              BRAUND, MR. OWEN HARRIS    male  22.000000
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.000000
# 2                               HEIKKINEN, MISS. LAINA  female  26.000000
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.000000
# 4                             ALLEN, MR. WILLIAM HENRY    male  35.000000
# ..                                                 ...     ...        ...
# 886                              MONTVILA, REV. JUOZAS    male  27.000000
# 887                       GRAHAM, MISS. MARGARET EDITH  female  19.000000
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female  29.699118
# 889                              BEHR, MR. KARL HOWELL    male  26.000000
# 890                                DOOLEY, MR. PATRICK    male  32.000000
#
#      SibSp  Parch            Ticket     Fare  ...         FareBucket  \
# 0        1      0         A/5 21171   7.2500  ...    (-0.001, 7.854]
# 1        1      0          PC 17599  71.2833  ...  (39.688, 512.329]
# 2        0      0  STON/O2. 3101282   7.9250  ...      (7.854, 10.5]
# 3        1      0            113803  53.1000  ...  (39.688, 512.329]
# 4        0      0            373450   8.0500  ...      (7.854, 10.5]
# ..     ...    ...               ...      ...  ...                ...
# 886      0      0            211536  13.0000  ...     (10.5, 21.679]
# 887      0      0            112053  30.0000  ...   (21.679, 39.688]
# 888      1      2        W./C. 6607  23.4500  ...   (21.679, 39.688]
# 889      0      0            111369  30.0000  ...   (21.679, 39.688]
# 890      0      0            370376   7.7500  ...    (-0.001, 7.854]
#
#     FamilySize IsChild  Title  Fare_norm Age_Groups       Last IsAlone  \
# 0            2   False     MR   0.014151      Adult     BRAUND   False
# 1            2   False    MRS   0.139136      Adult    CUMINGS   False
# 2            1   False   MISS   0.015469      Adult  HEIKKINEN    True
# 3            2   False    MRS   0.103644      Adult   FUTRELLE   False
# 4            1   False     MR   0.015713      Adult      ALLEN    True
# ..         ...     ...    ...        ...        ...        ...     ...
# 886          1   False    REV   0.025374      Adult   MONTVILA    True
# 887          1   False   MISS   0.058556      Adult     GRAHAM    True
# 888          4   False   MISS   0.045771      Adult   JOHNSTON   False
# 889          1   False     MR   0.058556      Adult       BEHR    True
# 890          1   False     MR   0.015127      Adult     DOOLEY    True
#
#     FarePerPerson  CumulativeSum
# 0         3.62500         7.2500
# 1        35.64165        78.5333
# 2         7.92500        86.4583
# 3        26.55000       139.5583
# 4         8.05000       147.6083
# ..            ...            ...
# 886      13.00000     28602.7493
# 887      30.00000     28632.7493
# 888       5.86250     28656.1993
# 889      30.00000     28686.1993
# 890       7.75000     28693.9493
#
# [891 rows x 22 columns]

# %% [markdown]
# Compare survival rate of people with cabin vs without cabin.

# %%
df["HasCabin"] = df["Cabin"].notna()
df.groupby("HasCabin")["Survived"].mean()
# Out:
# HasCabin
# False    0.299854
# True     0.666667
# Name: Survived, dtype: float64
