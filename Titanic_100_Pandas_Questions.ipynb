# %% [markdown]
# ### Question 1
# How do you load the Titanic CSV into a DataFrame?

# %% [markdown]
# ### Question 2
# How do you view the first 5 rows?

# %% [markdown]
# ### Question 3
# How do you view the last 10 rows?

# %% [markdown]
# ### Question 4
# How do you get the shape of the dataset?

# %% [markdown]
# ### Question 5
# How do you list all column names?

# %% [markdown]
# ### Question 6
# How many rows are present in the dataset?

# %% [markdown]
# ### Question 7
# How do you check the datatype of each column?

# %% [markdown]
# ### Question 8
# How many missing values does each column have?

# %% [markdown]
# ### Question 9
# How do you get summary statistics for numerical columns?

# %% [markdown]
# ### Question 10
# How do you display only the ‘Name’ column?

# %% [markdown]
# ### Question 11
# How do you select first 10 values in the ‘Age’ column?

# %% [markdown]
# ### Question 12
# How do you filter passengers older than 50?

# %% [markdown]
# ### Question 13
# How do you filter passengers who survived?

# %% [markdown]
# ### Question 14
# How do you select all rows where Sex == 'female'?

# %% [markdown]
# ### Question 15
# How many passengers embarked from 'S'?

# %% [markdown]
# ### Question 16
# How do you sort by Age (ascending)?

# %% [markdown]
# ### Question 17
# How do you sort by Fare (descending)?

# %% [markdown]
# ### Question 18
# How do you check how many unique Ticket values exist?

# %% [markdown]
# ### Question 19
# How do you drop the Cabin column?

# %% [markdown]
# ### Question 20
# How do you rename “Sex” to “Gender”?

# %% [markdown]
# ### Question 21
# Display rows where Age is between 20 and 40.

# %% [markdown]
# ### Question 22
# Filter passengers who paid more than 100 in Fare.

# %% [markdown]
# ### Question 23
# Count number of male vs female passengers.

# %% [markdown]
# ### Question 24
# What is the average fare by Pclass?

# %% [markdown]
# ### Question 25
# What is the average age of survivors vs non-survivors?

# %% [markdown]
# ### Question 26
# Find top 5 oldest passengers.

# %% [markdown]
# ### Question 27
# Find passengers with missing Age values.

# %% [markdown]
# ### Question 28
# Fill missing Age values with the mean age.

# %% [markdown]
# ### Question 29
# Replace missing Embarked values with the mode.

# %% [markdown]
# ### Question 30
# How many passengers have SibSp > 2?

# %% [markdown]
# ### Question 31
# Count passengers grouped by Embarked and Sex.

# %% [markdown]
# ### Question 32
# Find min, max, mean fare for each class.

# %% [markdown]
# ### Question 33
# Create a new column “FamilySize” = SibSp + Parch + 1.

# %% [markdown]
# ### Question 34
# Create a new column “IsChild” where Age < 18.

# %% [markdown]
# ### Question 35
# Count how many children survived.

# %% [markdown]
# ### Question 36
# Show survival rate per Pclass.

# %% [markdown]
# ### Question 37
# Show survival rate per Sex.

# %% [markdown]
# ### Question 38
# Which Ticket occurs most often?

# %% [markdown]
# ### Question 39
# Which Cabin letter appears the most?

# %% [markdown]
# ### Question 40
# How many passengers have Fare = 0?

# %% [markdown]
# ### Question 41
# Use groupby to compute average Age per Sex per Pclass.

# %% [markdown]
# ### Question 42
# Find the passenger who paid the highest fare.

# %% [markdown]
# ### Question 43
# Find rows where Name contains 'Mrs'.

# %% [markdown]
# ### Question 44
# Extract honorific title (Mr, Mrs, Miss, etc.) from Name.

# %% [markdown]
# ### Question 45
# Count survival rate for each title.

# %% [markdown]
# ### Question 46
# Find correlation between Age, Fare, Pclass, Survived.

# %% [markdown]
# ### Question 47
# Normalize the Fare column (0–1 scale).

# %% [markdown]
# ### Question 48
# Bin Age into categories: Child/Adult/Senior.

# %% [markdown]
# ### Question 49
# For each Embarked port, find the top 3 highest fares.

# %% [markdown]
# ### Question 50
# Find the name of the youngest surviving female.

# %% [markdown]
# ### Question 51
# Count how many passengers have the same last name.

# %% [markdown]
# ### Question 52
# Identify duplicate Ticket numbers.

# %% [markdown]
# ### Question 53
# Find average family size per Pclass.

# %% [markdown]
# ### Question 54
# Create a column “IsAlone” (FamilySize == 1).

# %% [markdown]
# ### Question 55
# Survival chance comparison: Alone vs Not alone.

# %% [markdown]
# ### Question 56
# Find the fare per person by dividing Fare / FamilySize.

# %% [markdown]
# ### Question 57
# Get the passenger with the longest name.

# %% [markdown]
# ### Question 58
# Compute median age per Pclass and fill missing ages class-wise.

# %% [markdown]
# ### Question 59
# Compare male vs female survival rate within each class.

# %% [markdown]
# ### Question 60
# Determine if fare distribution is right-skewed or left-skewed.

# %% [markdown]
# ### Question 61
# Find the age gap between the oldest and youngest passenger per class.

# %% [markdown]
# ### Question 62
# Create a pivot table showing survival by Sex and Pclass.

# %% [markdown]
# ### Question 63
# Find all family groups (same last name) with size > 3.

# %% [markdown]
# ### Question 64
# Identify passengers traveling with siblings AND parents.

# %% [markdown]
# ### Question 65
# Which Embarked port had the highest survival percentage?

# %% [markdown]
# ### Question 66
# Create a new column “FareBucket” using qcut into 5 bins.

# %% [markdown]
# ### Question 67
# Compare survival rate across FareBuckets.

# %% [markdown]
# ### Question 68
# Find which class had the largest fare variance.

# %% [markdown]
# ### Question 69
# Use apply to format Name into uppercase.

# %% [markdown]
# ### Question 70
# Extract ticket prefix (letters before numbers).

# %% [markdown]
# ### Question 71
# Count passengers by ticket prefix.

# %% [markdown]
# ### Question 72
# Group passengers by Cabin deck (first letter).

# %% [markdown]
# ### Question 73
# Find average survivor age per cabin deck.

# %% [markdown]
# ### Question 74
# Determine if high-fare passengers survived more often.

# %% [markdown]
# ### Question 75
# Calculate survival rate per family size.

# %% [markdown]
# ### Question 76
# Identify which family size is most likely to survive.

# %% [markdown]
# ### Question 77
# Compute z-score for Fare and detect outliers.

# %% [markdown]
# ### Question 78
# Compute z-score for Age and detect outliers.

# %% [markdown]
# ### Question 79
# Create a cumulative sum of Fare sorted by PassengerId.

# %% [markdown]
# ### Question 80
# Compare survival rate of people with cabin vs without cabin.

# %% [markdown]
# ### Question 81
# Predict missing Cabin deck using Pclass and Fare.

# %% [markdown]
# ### Question 82
# Reconstruct families using last name + ticket grouping.

# %% [markdown]
# ### Question 83
# Detect multi-ticket travel groups (same Ticket, diff names).

# %% [markdown]
# ### Question 84
# Compute survival rate for multi-ticket groups.

# %% [markdown]
# ### Question 85
# Find if groups with higher fare-per-person survived more.

# %% [markdown]
# ### Question 86
# Compute conditional survival probability: P(Survived | Sex, Pclass, FareBucket).

# %% [markdown]
# ### Question 87
# Identify outlier groups where all adults died but children survived.

# %% [markdown]
# ### Question 88
# Build a custom function to classify passengers as Rich/Middle/Poor.

# %% [markdown]
# ### Question 89
# For each FareBucket, find top 3 most common surnames.

# %% [markdown]
# ### Question 90
# Cluster passengers by Age, Fare, Pclass using pandas only.

# %% [markdown]
# ### Question 91
# Fill missing Age using median age per title.

# %% [markdown]
# ### Question 92
# Create a feature-rich dataset (Title, Deck, FamilySize, FarePerPerson).

# %% [markdown]
# ### Question 93
# Compute survival odds ratio for Male vs Female.

# %% [markdown]
# ### Question 94
# Compute survival odds ratio for 1st class vs 3rd class.

# %% [markdown]
# ### Question 95
# Create a multi-index DataFrame indexed by [Sex, Pclass, Embarked].

# %% [markdown]
# ### Question 96
# Unstack this multi-index to form a survival matrix.

# %% [markdown]
# ### Question 97
# Find survival probability for female, Age < 18, Pclass = 1, Fare > 50.

# %% [markdown]
# ### Question 98
# Compute Gini impurity for survival split by Sex.

# %% [markdown]
# ### Question 99
# Compute entropy of survival distribution.

# %% [markdown]
# ### Question 100
# Build a rule-based survival predictor and compare accuracy.
